# %%
from streamjoy import stream, config
import pandas as pd


df = pd.read_csv("gapminder.csv")
config["max_frames"] = 3
config["ending_pause"] = 0
sj = stream(df)
assert sj.max_frames == 3
# Out:
# [WARNING] 03:39PM: No 'max_frames' specified; using the default 3. Suppress this by passing 'max_frames'.
# [WARNING] 03:39PM: No 'max_frames' specified; using the default 3 / 50 frames. Pass `-1` to use all frames. Suppress this by passing 'max_frames'.
# [WARNING] 03:39PM: No 'x' specified; using the default 'Unnamed: 0' from the dataframe. Suppress this by passing 'x'.
# [WARNING] 03:39PM: No 'y' specified; using the default 'Year' from the dataframe. Suppress this by passing 'y'.

# %%
from imageio.v3 import improps
# Out:
# <Client: 'tcp://127.0.0.1:55181' processes=4 threads=8, memory=16.00 GiB>
# [SUCCESS] 03:39PM: Saved stream to memory.
#                     <video controls>
#                         <source src="data:video/mp4;base64,..." type="video/mp4">
#                     </video>
# [WARNING] 03:39PM: Format mov,mp4,m4a,3gp,3g2,mj2 detected only with low score of 1, misdetection possible!
